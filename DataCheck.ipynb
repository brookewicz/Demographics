# %% [markdown]
# # Data Check

# %% [markdown]
# ## qa/qc to double check data after sampling trips
# - Do sample health statuses match colony conditions?
# - Check on 'dead' corals: did they stay dead (if not, change condition bc they were never dead),were they checked on, were any samples taken (possibly from the wrong coral?)
# - Did we take samples from all live corals - 2 per coral, 3 on immune trips
#
# - Summary stats:
#     - Compare # of expected samples to how many samples were taken
#     - Num of corals at each transect (how does this compare to the previous trip?)
#     - Num of corals within each condition

# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/CBC_metagenomics/Demographics'

# %%
# upload sample data 
sample_data=pd.read_csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata/CBC_samples.csv',index_col="Tubelabel_species")

# %%
# convert dates to str
sample_data['Month_year'] = sample_data['Month_year'].astype(str)
# remove the decimal point
sample_data['Month_year'] = sample_data['Month_year'].str.replace('.0', '')
# add leading zeros where necessary
sample_data['Month_year'] = sample_data['Month_year'].str.pad(width=6, side='left', fillchar='0')
sample_data['Month_year']

# Extract month and year to make separate columns 
sample_data.loc[:,'Month'] = sample_data.loc[:,'Month_year'].str[0:2]
sample_data.loc[:,'Year'] = sample_data.loc[:,'Month_year'].str[2:]

# %%
sample_data.head()
# Out:
#                            Month_year Country Location CollectionDate  \
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV      122022     BEL      CBC        12/5/22
# 092023_BEL_CBC_T1_171_PAST     092023     BEL      CBC        9/25/23
# 092023_BEL_CBC_T1_172_PAST     092023     BEL      CBC        9/25/23
# 092023_BEL_CBC_T1_173_SSID     092023     BEL      CBC        9/25/23
# 092023_BEL_CBC_T1_174_MCAV     092023     BEL      CBC        9/25/23
#
#                            Transect  TransectNum OldTagNum NewTagNum Species  \
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV    CURLEW            4       NaN        77    OFAV
# 092023_BEL_CBC_T1_171_PAST   CBC30N            1       NaN         2    PAST
# 092023_BEL_CBC_T1_172_PAST   CBC30N            1       NaN        21    PAST
# 092023_BEL_CBC_T1_173_SSID   CBC30N            1       NaN         3    SSID
# 092023_BEL_CBC_T1_174_MCAV   CBC30N            1       NaN        24    MCAV
#
#                            Time_sampled  ...    Sample_type SampleNum  \
# Tubelabel_species                        ...
# 122022_BEL_CBC_T4_18_OFAV           NaN  ...    Core_frozen        18
# 092023_BEL_CBC_T1_171_PAST          NaN  ...  Core_RNAlater       171
# 092023_BEL_CBC_T1_172_PAST          NaN  ...  Core_RNAlater       172
# 092023_BEL_CBC_T1_173_SSID          NaN  ...  Core_RNAlater       173
# 092023_BEL_CBC_T1_174_MCAV          NaN  ...  Core_RNAlater       174
#
#                            Health_status   Sampling_notes  \
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV        Healthy              NaN
# 092023_BEL_CBC_T1_171_PAST       Healthy          CLP 90%
# 092023_BEL_CBC_T1_172_PAST       Healthy            No CL
# 092023_BEL_CBC_T1_173_SSID       Healthy  CLP 80%; DC 20%
# 092023_BEL_CBC_T1_174_MCAV       Healthy          CLP 10%
#
#                            Sample_physical_location  \
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV                       NaN
# 092023_BEL_CBC_T1_171_PAST       UML_NARWHAL_R1_B10
# 092023_BEL_CBC_T1_172_PAST       UML_NARWHAL_R1_B10
# 092023_BEL_CBC_T1_173_SSID       UML_NARWHAL_R1_B10
# 092023_BEL_CBC_T1_174_MCAV       UML_NARWHAL_R1_B10
#
#                            Extraction_physical_location Date_sequenced Notes  \
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV                           NaN            NaN   NaN
# 092023_BEL_CBC_T1_171_PAST                          NaN            NaN   NaN
# 092023_BEL_CBC_T1_172_PAST                          NaN            NaN   NaN
# 092023_BEL_CBC_T1_173_SSID                          NaN            NaN   NaN
# 092023_BEL_CBC_T1_174_MCAV                          NaN            NaN   NaN
#
#                            Month  Year
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV     12  2022
# 092023_BEL_CBC_T1_171_PAST    09  2023
# 092023_BEL_CBC_T1_172_PAST    09  2023
# 092023_BEL_CBC_T1_173_SSID    09  2023
# 092023_BEL_CBC_T1_174_MCAV    09  2023
#
# [5 rows x 21 columns]

# %%
# upload colony data 
colony_data=pd.read_csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata/CBC_ColonyData.csv')

# %%
# convert integers to strings 
colony_data['NewTagNum'] = colony_data['NewTagNum'].astype(str)
colony_data['TransectNum'] = colony_data['TransectNum'].astype(str)
sample_data['NewTagNum'] = sample_data['NewTagNum'].astype(str)
sample_data['TransectNum'] = sample_data['TransectNum'].astype(str)

# %%
# drop 'unnamed' col
colony_data = colony_data.drop(columns=['Unnamed: 0'])

# %%
# fix caps issues 
colony_data['062024_Condition'].unique()
# Out:
# array(['Not_Visited', 'Healthy', 'Diseased', 'Dead', 'DC',
#        'Diseased_Other', 'Not_visited', 'not_visited'], dtype=object)

# %%
# fix caps issues 
colony_data = colony_data.applymap(lambda x: 'Not_Visited' if isinstance(x, str) and x.lower() == 'not_visited' else x)
colony_data['062024_Condition'].unique()
# Out:
# /tmp/ipykernel_1111700/903712831.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   colony_data = colony_data.applymap(lambda x: 'Not_Visited' if isinstance(x, str) and x.lower() == 'not_visited' else x)
# array(['Not_Visited', 'Healthy', 'Diseased', 'Dead', 'DC',
#        'Diseased_Other'], dtype=object)

# %%
# add tag id to both sample and colony data to match colonies
colony_data['ID'] = colony_data['Species'] + '_T' + colony_data['TransectNum'] + '_' + colony_data['NewTagNum']
sample_data['ID'] = sample_data['Species'] + '_T' + sample_data['TransectNum'] + '_' + sample_data['NewTagNum']

# %%
colony_data['ID']
# Out:
# 0       SSID_T1_1
# 1       PAST_T1_2
# 2       SSID_T1_3
# 3       PSTR_T1_4
# 4       SSID_T1_5
#           ...
# 214    OFAV_T6_32
# 215    OANN_T6_33
# 216    OFAV_T6_34
# 217    OFAV_T6_35
# 218    OANN_T6_36
# Name: ID, Length: 219, dtype: object

# %%
sample_data['ID']
# Out:
# Tubelabel_species
# 122022_BEL_CBC_T4_18_OFAV     OFAV_T4_77
# 092023_BEL_CBC_T1_171_PAST     PAST_T1_2
# 092023_BEL_CBC_T1_172_PAST    PAST_T1_21
# 092023_BEL_CBC_T1_173_SSID     SSID_T1_3
# 092023_BEL_CBC_T1_174_MCAV    MCAV_T1_24
#                                  ...
# 62024_BEL_CBC_T4_1461_OFAV    OFAV_T4_78
# NaN                           OFAV_T4_78
# NaN                           MCAV_T4_76
# 62024_BEL_CBC_T4_1464_MCAV    MCAV_T4_76
# NaN                           MCAV_T4_76
# Name: ID, Length: 2103, dtype: object

# %%
# make 'ID' the index for sample and colony data 
sample_data.set_index('ID',inplace=True)
colony_data.set_index('ID',inplace=True)

# %%
#drop any accidental samples
sample_data = sample_data[sample_data['NewTagNum'] != "AS"]

# %%
sample_data['Sample_type'].unique()
# Out:
# array(['Core_frozen', 'Core_RNAlater', 'Core_EtOH', 'Probiotics',
#        'Immune', 'TEM', nan, 'Syringe'], dtype=object)

# %%
# filter sample data to just get one sample from each date
uml_sample = sample_data[
    (sample_data['Sample_type'] == "Core_EtOH") | 
    (sample_data['Sample_type'] == "Core_RNAlater")
]

# %%
# view na
columns=["Month_year","Sample_type","Health_status"]
uml_sample.loc[uml_sample['Health_status'].isna(),columns]
# Out:
# Empty DataFrame
# Columns: [Month_year, Sample_type, Health_status]
# Index: []

# %%
# change all disease entries to diseased for easy checking 
diseased_rows=uml_sample['Health_status'].str.contains("Diseased")
diseased_rows
uml_sample.loc[diseased_rows, 'Health_status']="Diseased"

# %%
# change sample 102019 sample month years to 062019 since they are all grouped together in the condition data
uml_sample.loc[uml_sample['Month_year']=="102019","Month_year"]="062019"

# %%
# create for loop, cycle thru each data and see if sample health statuses match colony conditions 
# filter for etoh and rna later or will it work without??
# get unique values for month year 
dates=uml_sample['Month_year'].unique().tolist()
dates
# Out:
# ['092023',
#  '122022',
#  '052022',
#  '042024',
#  '062019',
#  '112023',
#  '122023',
#  '012024',
#  '022024',
#  '062024']

# %%
# replace NAs with Not_Visited
condition_cols=colony_data.columns[colony_data.columns.str.contains("Condition")]
colony_data[condition_cols] = colony_data[condition_cols].fillna("Not_Visited")

# %%
# check unique values in conditions
for date in dates:
    print(date,colony_data[f'{date}_Condition'].unique())
colony_data[condition_cols].describe()
# Out:
# 092023 ['Diseased' 'CLP,CLB' 'Not_Visited' 'Dead' 'CLP' 'Healthy' 'Diseased, CLB'
#  'CLB' 'Diseased, CLP' 'CLP,DC' 'DC']
# 122022 ['Diseased' 'Healthy' 'Dead' 'DC' 'Not_Visited' 'CLB,DC' 'CLB']
# 052022 ['Diseased' 'Healthy' 'DC' 'Dead' 'Not_Visited' 'CLB,DC']
# 042024 ['Diseased' 'Not_Visited' 'Healthy' 'Dead' 'Diseased, CLP' 'CLP'
#  'Diseased_Other' 'DC' 'Diseased, DC' 'Diseased,DC']
# 062019 ['Healthy' 'Not_Visited']
# 112023 ['Not_Visited' 'CLB' 'CLP,CLB' 'CLP' 'Dead' 'Healthy' 'Diseased']
# 122023 ['Not_Visited' 'CLB' 'Healthy' 'Dead' 'CLP, DC' 'CLP' 'CLP,CLB' 'Diseased']
# 012024 ['Diseased' 'CLP,CLB' 'Healthy' 'Not_Visited' 'Dead' 'CLB' 'CLP' 'CLP,DC'
#  'Diseased_Other' 'DC']
# 022024 ['Not_Visited' 'Healthy' 'DC' 'Dead' 'Diseased' 'CLB' 'CLP'
#  'Diseased_Other']
# 062024 ['Not_Visited' 'Healthy' 'Diseased' 'Dead' 'DC' 'Diseased_Other']
#        062019_Condition 052022_Condition 122022_Condition 092023_Condition  \
# count               219              219              219              219
# unique                2                6                7               11
# top         Not_Visited      Not_Visited      Not_Visited      Not_Visited
# freq                113              105               83              100
#
#        112023_Condition 122023_Condition 012024_Condition 022024_Condition  \
# count               219              219              219              219
# unique                7                8               10                8
# top         Not_Visited      Not_Visited      Not_Visited      Not_Visited
# freq                139              139               77              138
#
#        042024_Condition 062024_Condition
# count               219              219
# unique               10                6
# top             Healthy      Not_Visited
# freq                107              161

# %%
# create dfs by coral id incl condition and sample health status at each time point 
dataframes_dict = {}
# run for loop
for date in dates:
    # get corresponding condition col in colony data for each data 
    condition_col = colony_data.loc[:, colony_data.columns.str.contains(f'{date}_Condition')]
    # convert data_condition col into df and store in dict 
    condition_df=pd.DataFrame(condition_col)
    dataframes_dict[date] = condition_df
    # filter out not_visited into separate df and save in dict 
    visited_conditions = condition_df[
        (condition_df[f'{date}_Condition'] != "Not_Visited") &
        (condition_df[f'{date}_Condition'] != "Dead")
    ]
    dataframes_dict[f'{date}_visited'] = visited_conditions
    # make df containing samples at the same point, showing their sample type and health status
    sample_health = uml_sample[uml_sample["Month_year"] == date][["Sample_type", "Health_status"]]
    sample_health_condensed = sample_health.groupby(sample_health.index).first()
     # Merge condition data with sample health data
    merged_df = pd.merge(visited_conditions, sample_health_condensed, left_index=True, right_index=True, how='left')
    # store the merged DataFrame in the dictionary
    dataframes_dict[f'{date}_samples'] = merged_df
     # apply groupby(...).first() before merging with all condition data
    sample_health_all_condensed = sample_health.groupby(sample_health.index).first()
    # can also merge non-visited 
    merged_all=pd.merge(condition_df, sample_health_all_condensed, left_index=True, right_index=True, how='left')
    dataframes_dict[f'{date}_all'] = merged_all

# %%
# right now, manually look at each date...going to add all non-sampled into one df for easy viewing 
# also want to: sum up alive and visited corals and number of samples taken from each individual colony 
dataframes_dict['062024_samples'].shape
# Out:
# (38, 3)

# %%
print(dataframes_dict['062024_all'].shape)
dataframes_dict['062024_all'].head()
# Out:
# (219, 3)
#           062024_Condition    Sample_type Health_status
# ID
# SSID_T1_1      Not_Visited            NaN           NaN
# PAST_T1_2          Healthy  Core_RNAlater       Healthy
# SSID_T1_3         Diseased  Core_RNAlater      Diseased
# PSTR_T1_4      Not_Visited            NaN           NaN
# SSID_T1_5      Not_Visited            NaN           NaN

# %%
print(dataframes_dict['062024'].shape)
print(dataframes_dict['062024'])
print(dataframes_dict['062024_visited'].shape)
print(dataframes_dict['062024_visited'])
print(sample_health.shape)
print(sample_health)
# Out:
# (219, 1)
#            062024_Condition
# ID
# SSID_T1_1       Not_Visited
# PAST_T1_2           Healthy
# SSID_T1_3          Diseased
# PSTR_T1_4       Not_Visited
# SSID_T1_5       Not_Visited
# ...                     ...
# OFAV_T6_32      Not_Visited
# OANN_T6_33      Not_Visited
# OFAV_T6_34      Not_Visited
# OFAV_T6_35      Not_Visited
# OANN_T6_36      Not_Visited
#
# [219 rows x 1 columns]
# (38, 1)
#            062024_Condition
# ID
# PAST_T1_2           Healthy
# SSID_T1_3          Diseased
# PSTR_T1_12          Healthy
# PAST_T1_21          Healthy
# MCAV_T1_24          Healthy
# ORBI_T1_25          Healthy
# SSID_T2_51          Healthy
# MCAV_T2_55          Healthy
# PAST_T2_57          Healthy
# MCAV_T2_60          Healthy
# PAST_T2_63          Healthy
# SSID_T2_66         Diseased
# PAST_T2_68          Healthy
# MCAV_T2_69          Healthy
# SSID_T2_72         Diseased
# SSID_T2_73               DC
# OFAV_T2_76          Healthy
# OFAV_T2_79          Healthy
# SSID_T2_99         Diseased
# MCAV_T3_2    Diseased_Other
# SSID_T3_5           Healthy
# PAST_T3_10          Healthy
# MCAV_T3_14          Healthy
# PSTR_T3_20          Healthy
# MCAV_T3_21          Healthy
# PAST_T3_24          Healthy
# SSID_T3_33               DC
# PAST_T3_34          Healthy
# OFAV_T3_38          Healthy
# OFAV_T3_39          Healthy
# OFAV_T3_66          Healthy
# PSTR_T3_70          Healthy
# MCAV_T4_28          Healthy
# MCAV_T4_30          Healthy
# MCAV_T4_76          Healthy
# OFAV_T4_78          Healthy
# PSTR_T4_79          Healthy
# PSTR_T4_98          Healthy
# (37, 2)
#                Sample_type Health_status
# ID
# OFAV_T3_38   Core_RNAlater       Healthy
# OFAV _T3_66  Core_RNAlater       Healthy
# OFAV_T3_39   Core_RNAlater       Healthy
# SSID_T3_33   Core_RNAlater       Healthy
# PAST_T3_34   Core_RNAlater       Healthy
# MCAV_T3_2    Core_RNAlater      Diseased
# MCAV_T3_2    Core_RNAlater      Diseased
# SSID_T3_5    Core_RNAlater       Healthy
# PAST_T3_10   Core_RNAlater       Healthy
# MCAV_T3_14   Core_RNAlater       Healthy
# PSTR_T3_20   Core_RNAlater       Healthy
# PSTR_T3_70   Core_RNAlater       Healthy
# MCAV_T3_21   Core_RNAlater       Healthy
# SSID_T1_3    Core_RNAlater      Diseased
# SSID_T1_3    Core_RNAlater      Diseased
# OANN_T1_25   Core_RNAlater       Healthy
# PSTR_T1_12   Core_RNAlater       Healthy
# MCAV_T1_24   Core_RNAlater       Healthy
# PAST_T1_2    Core_RNAlater       Healthy
# PAST_T1_13   Core_RNAlater       Healthy
# SSID_T2_72   Core_RNAlater      Diseased
# MCAV_T2_69   Core_RNAlater       Healthy
# PAST_T2_57   Core_RNAlater       Healthy
# MCAV_T2_60   Core_RNAlater       Healthy
# PAST_T2_63   Core_RNAlater       Healthy
# OFAV_T2_76   Core_RNAlater       Healthy
# SSID_T2_73   Core_RNAlater       Healthy
# PAST_T2_68   Core_RNAlater       Healthy
# SSID_T2_99   Core_RNAlater      Diseased
# MCAV_T2_55   Core_RNAlater       Healthy
# OFAV_T2_79   Core_RNAlater       Healthy
# MCAV_T4_28   Core_RNAlater       Healthy
# PSTR_T4_98   Core_RNAlater       Healthy
# PSTR_T4_79   Core_RNAlater       Healthy
# MCAV_T4_30   Core_RNAlater       Healthy
# OFAV_T4_78   Core_RNAlater       Healthy
# MCAV_T4_76   Core_RNAlater       Healthy

# %%
# cycle thru samples dicts and view any mismatches 
# Initialize a list to store mismatches
mismatches = []

for date in dates:
    # Access the DataFrame from the dictionary
    df = dataframes_dict[f'{date}_all']

    # Condition 1: If 'Not_Visited' or 'Dead', there should be no sample
    condition1_violations = df[
        ((df[f'{date}_Condition'] == "Not_Visited") | (df[f'{date}_Condition'] == "Dead")) &
        (df['Sample_type'].notna() | df['Health_status'].notna())
    ]
    
    if not condition1_violations.empty:
        mismatches.append((date, 'Condition 1 Violations', condition1_violations))

    # Condition 2: If alive, condition should match health status of the sample
    condition2_violations = df[
        (df[f'{date}_Condition'] != "Not_Visited") & 
        (df[f'{date}_Condition'] != "Dead") &
        (df['Health_status'].notna()) & 
        (df[f'{date}_Condition'] != df['Health_status'])
    ]

    if not condition2_violations.empty:
        mismatches.append((date, 'Condition 2 Violations', condition2_violations))

# If there are mismatches, print or export them for review
if mismatches:
    for mismatch in mismatches:
        date, violation_type, df = mismatch
        print(f"Date: {date} - {violation_type}")
        print(df)
        print("\n")
else:
    print(date,"No mismatches found.")
# chatgpt code
# Out:
# Date: 092023 - Condition 2 Violations
#            092023_Condition    Sample_type Health_status
# ID
# PAST_T1_2           CLP,CLB  Core_RNAlater       Healthy
# SSID_T1_3          Diseased  Core_RNAlater       Healthy
# MCAV_T1_7               CLP  Core_RNAlater       Healthy
# SSID_T1_17    Diseased, CLB  Core_RNAlater      Diseased
# PAST_T1_21              CLP  Core_RNAlater       Healthy
# MCAV_T1_24              CLP  Core_RNAlater       Healthy
# DLAB_T1_35              CLP  Core_RNAlater       Healthy
# OFAV_T2_29          CLP,CLB  Core_RNAlater       Healthy
# OANN_T2_30          CLP,CLB  Core_RNAlater      Diseased
# PSTR_T2_32              CLP  Core_RNAlater       Healthy
# PSTR_T2_54    Diseased, CLP  Core_RNAlater      Diseased
# MCAV_T2_55              CLP  Core_RNAlater       Healthy
# MCAV_T2_59              CLP  Core_RNAlater       Healthy
# MCAV_T2_60          CLP,CLB  Core_RNAlater       Healthy
# CNAT_T2_64              CLP  Core_RNAlater       Healthy
# SSID_T2_66              CLB  Core_RNAlater      Diseased
# SSID_T2_67              CLB  Core_RNAlater      Diseased
# SSID_T2_71              CLP  Core_RNAlater      Diseased
# SSID_T2_72              CLB  Core_RNAlater       Healthy
# SSID_T2_73          CLP,CLB  Core_RNAlater       Healthy
# SSID_T2_74         Diseased  Core_RNAlater       Healthy
# OANN_T2_77          CLP,CLB  Core_RNAlater       Healthy
# OFAV_T2_79              CLB  Core_RNAlater       Healthy
# OFAV_T2_80          CLP,CLB  Core_RNAlater      Diseased
# SSID_T2_99              CLP  Core_RNAlater       Healthy
# PAST_T3_6               CLB  Core_RNAlater       Healthy
# PAST_T3_8               CLB  Core_RNAlater       Healthy
# PAST_T3_10              CLP  Core_RNAlater       Healthy
# PAST_T3_18         Diseased  Core_RNAlater       Healthy
# PSTR_T3_20              CLP  Core_RNAlater       Healthy
# SSID_T3_33           CLP,DC  Core_RNAlater       Healthy
# SSID_T3_36               DC  Core_RNAlater       Healthy
# OANN_T3_68              CLB  Core_RNAlater       Healthy
# PSTR_T3_70              CLP  Core_RNAlater       Healthy
# DLAB_T3_73              CLP  Core_RNAlater       Healthy
# PSTR_T3_75              CLP  Core_RNAlater       Healthy
# OFAV_T4_77          Healthy  Core_RNAlater      Diseased
# OFAV_T4_92          Healthy  Core_RNAlater      Diseased
# DLAB_T4_93          Healthy  Core_RNAlater      Diseased
#
#
# Date: 122022 - Condition 2 Violations
#            122022_Condition Sample_type Health_status
# ID
# OANN_T1_23               DC   Core_EtOH       Healthy
# SSID_T2_72           CLB,DC   Core_EtOH       Healthy
# SSID_T2_73              CLB   Core_EtOH       Healthy
# MCAV_T3_71               DC   Core_EtOH       Healthy
#
#
# Date: 052022 - Condition 1 Violations
#            052022_Condition Sample_type Health_status
# ID
# MCAV_T2_61             Dead   Core_EtOH       Healthy
#
#
# Date: 052022 - Condition 2 Violations
#            052022_Condition Sample_type Health_status
# ID
# OANN_T1_23               DC   Core_EtOH       Healthy
# SSID_T2_72           CLB,DC   Core_EtOH       Healthy
#
#
# Date: 042024 - Condition 1 Violations
#            042024_Condition    Sample_type Health_status
# ID
# MCAV_T3_2       Not_Visited  Core_RNAlater       Healthy
# SSID_T3_3       Not_Visited  Core_RNAlater      Diseased
# PSTR_T3_4       Not_Visited  Core_RNAlater       Healthy
# SSID_T3_5       Not_Visited  Core_RNAlater       Healthy
# PAST_T3_7       Not_Visited  Core_RNAlater       Healthy
# PAST_T3_13      Not_Visited  Core_RNAlater       Healthy
# OFAV_T3_66      Not_Visited  Core_RNAlater       Healthy
# MCAV_T5_64      Not_Visited  Core_RNAlater       Healthy
#
#
# Date: 042024 - Condition 2 Violations
#            042024_Condition    Sample_type Health_status
# ID
# SSID_T1_17    Diseased, CLP  Core_RNAlater      Diseased
# OANN_T1_22              CLP  Core_RNAlater      Diseased
# OANN_T1_23         Diseased  Core_RNAlater       Healthy
# OANN_T2_30              CLP  Core_RNAlater       Healthy
# PSTR_T2_54   Diseased_Other  Core_RNAlater      Diseased
# SSID_T2_72         Diseased  Core_RNAlater       Healthy
# OANN_T2_77              CLP  Core_RNAlater      Diseased
# SSID_T2_99               DC  Core_RNAlater      Diseased
# PAST_T3_18         Diseased  Core_RNAlater       Healthy
# SSID_T3_28     Diseased, DC  Core_RNAlater      Diseased
# SSID_T3_36      Diseased,DC  Core_RNAlater      Diseased
# PSTR_T3_75          Healthy  Core_RNAlater      Diseased
# OFAV_T4_78              CLP  Core_RNAlater       Healthy
# PSTR_T4_98              CLP  Core_RNAlater       Healthy
# OANN_T5_32              CLP  Core_RNAlater       Healthy
# OANN_T5_33              CLP  Core_RNAlater       Healthy
# OANN_T5_34              CLP  Core_RNAlater       Healthy
# MCAV_T5_57               DC  Core_RNAlater       Healthy
# MCAV_T5_65               DC  Core_RNAlater       Healthy
# MCAV_T5_69               DC  Core_RNAlater       Healthy
# OFAV_T6_21              CLP  Core_RNAlater       Healthy
# PSTR_T6_27              CLP  Core_RNAlater       Healthy
#
#
# Date: 062019 - Condition 2 Violations
#            062019_Condition Sample_type Health_status
# ID
# SSID_T2_51          Healthy   Core_EtOH      Diseased
#
#
# Date: 112023 - Condition 2 Violations
#            112023_Condition    Sample_type Health_status
# ID
# PAST_T1_2               CLB  Core_RNAlater       Healthy
# SSID_T1_3           CLP,CLB  Core_RNAlater       Healthy
# PSTR_T1_12              CLP  Core_RNAlater       Healthy
# PAST_T1_21              CLP  Core_RNAlater       Healthy
# MCAV_T1_24              CLP  Core_RNAlater       Healthy
# MCAV_T2_55              CLP  Core_RNAlater       Healthy
# PAST_T2_57          CLP,CLB  Core_RNAlater       Healthy
# MCAV_T2_60              CLP  Core_RNAlater       Healthy
# PAST_T2_63          CLP,CLB  Core_RNAlater       Healthy
# MCAV_T2_69              CLP  Core_RNAlater       Healthy
# SSID_T2_72          CLP,CLB  Core_RNAlater       Healthy
# SSID_T2_73              CLB  Core_RNAlater       Healthy
# OFAV_T2_79          CLP,CLB  Core_RNAlater       Healthy
# SSID_T2_99              CLB  Core_RNAlater       Healthy
# MCAV_T3_2               CLP  Core_RNAlater       Healthy
# PAST_T3_6               CLB  Core_RNAlater       Healthy
# PAST_T3_10              CLB  Core_RNAlater       Healthy
# MCAV_T3_14              CLP  Core_RNAlater       Healthy
# PSTR_T3_20              CLP  Core_RNAlater       Healthy
# MCAV_T3_21          CLP,CLB  Core_RNAlater       Healthy
# SSID_T3_33          CLP,CLB  Core_RNAlater       Healthy
# PAST_T3_34              CLP  Core_RNAlater       Healthy
# PSTR_T3_70          CLP,CLB  Core_RNAlater       Healthy
# MCAV_T4_30              CLP  Core_RNAlater       Healthy
# MCAV_T4_76              CLP  Core_RNAlater       Healthy
# OFAV_T4_78              CLP  Core_RNAlater       Healthy
# PSTR_T4_79              CLP  Core_RNAlater       Healthy
# PSTR_T4_98              CLB  Core_RNAlater       Healthy
#
#
# Date: 122023 - Condition 2 Violations
#            122023_Condition    Sample_type Health_status
# ID
# PAST_T1_2               CLB  Core_RNAlater       Healthy
# PAST_T1_21          CLP, DC  Core_RNAlater       Healthy
# MCAV_T2_55          CLP,CLB  Core_RNAlater       Healthy
# PAST_T2_57          CLP,CLB  Core_RNAlater       Healthy
# MCAV_T2_60              CLB  Core_RNAlater       Healthy
# PAST_T2_63          CLP,CLB  Core_RNAlater       Healthy
# SSID_T2_72              CLB  Core_RNAlater       Healthy
# SSID_T2_73              CLB  Core_RNAlater       Healthy
# OFAV_T2_79              CLP  Core_RNAlater       Healthy
# SSID_T2_99              CLP  Core_RNAlater       Healthy
# MCAV_T3_2               CLP  Core_RNAlater       Healthy
# PAST_T3_6               CLB  Core_RNAlater       Healthy
# MCAV_T3_21              CLP  Core_RNAlater       Healthy
# PSTR_T3_70          CLP,CLB  Core_RNAlater       Healthy
# MCAV_T4_76              CLP  Core_RNAlater       Healthy
# OFAV_T4_78              CLP  Core_RNAlater       Healthy
# PSTR_T4_79              CLP  Core_RNAlater       Healthy
# PSTR_T4_98          CLP,CLB  Core_RNAlater       Healthy
#
#
# Date: 012024 - Condition 2 Violations
#            012024_Condition    Sample_type Health_status
# ID
# PAST_T1_21              CLP  Core_RNAlater       Healthy
# MCAV_T2_55              CLP  Core_RNAlater       Healthy
# SSID_T2_72              CLB  Core_RNAlater       Healthy
# SSID_T2_73              CLB  Core_RNAlater       Healthy
# SSID_T2_99              CLB  Core_RNAlater       Healthy
# MCAV_T3_2    Diseased_Other  Core_RNAlater       Healthy
# SSID_T3_33          CLP,CLB  Core_RNAlater       Healthy
# PAST_T3_34              CLP  Core_RNAlater       Healthy
# MCAV_T4_30              CLP  Core_RNAlater       Healthy
# OFAV_T4_78              CLP  Core_RNAlater       Healthy
# PSTR_T4_98              CLB  Core_RNAlater       Healthy
# OANN_T5_32              CLP  Core_RNAlater       Healthy
# OANN_T5_33              CLP  Core_RNAlater       Healthy
# OANN_T5_34              CLP  Core_RNAlater       Healthy
# OFAV_T5_35              CLP  Core_RNAlater       Healthy
# OFAV_T5_41              CLP  Core_RNAlater       Healthy
# OFAV_T5_43              CLP  Core_RNAlater       Healthy
# OANN_T5_47              CLP  Core_RNAlater       Healthy
# MCAV_T5_54              CLP  Core_RNAlater       Healthy
# MCAV_T5_57               DC  Core_RNAlater       Healthy
# MCAV_T5_65               DC  Core_RNAlater       Healthy
# MCAV_T5_69               DC  Core_RNAlater       Healthy
#
#
# Date: 022024 - Condition 2 Violations
#            022024_Condition    Sample_type Health_status
# ID
# SSID_T1_3                DC  Core_RNAlater       Healthy
# SSID_T2_73              CLB  Core_RNAlater       Healthy
# SSID_T2_99              CLP  Core_RNAlater       Healthy
# MCAV_T3_2    Diseased_Other  Core_RNAlater      Diseased
# PAST_T3_10              CLB  Core_RNAlater       Healthy
# OFAV_T4_78              CLP  Core_RNAlater       Healthy
# PSTR_T4_98              CLP  Core_RNAlater       Healthy
#
#
# Date: 062024 - Condition 1 Violations
#            062024_Condition    Sample_type Health_status
# ID
# PAST_T1_13             Dead  Core_RNAlater       Healthy
#
#
# Date: 062024 - Condition 2 Violations
#            062024_Condition    Sample_type Health_status
# ID
# SSID_T2_73               DC  Core_RNAlater       Healthy
# MCAV_T3_2    Diseased_Other  Core_RNAlater      Diseased
# SSID_T3_33               DC  Core_RNAlater       Healthy

# %%
## Summary stats 
# each time point, number of corals, number of live corals, num of samples divided by type 
dataframes_dict['062019_all']
# Out:
#            062019_Condition Sample_type Health_status
# ID
# SSID_T1_1           Healthy   Core_EtOH       Healthy
# PAST_T1_2           Healthy   Core_EtOH       Healthy
# SSID_T1_3           Healthy   Core_EtOH       Healthy
# PSTR_T1_4           Healthy   Core_EtOH       Healthy
# SSID_T1_5           Healthy   Core_EtOH       Healthy
# ...                     ...         ...           ...
# OFAV_T6_32      Not_Visited         NaN           NaN
# OANN_T6_33      Not_Visited         NaN           NaN
# OFAV_T6_34      Not_Visited         NaN           NaN
# OFAV_T6_35      Not_Visited         NaN           NaN
# OANN_T6_36      Not_Visited         NaN           NaN
#
# [219 rows x 3 columns]

# %%
# summary df plan  
#split by transect??
#df cols:       # tagged, # newly tagged, # total tagged (add the first two, should equal 219), # uml samples, # frozen, # immune
#rows = dates

# %%
colony_data['Date_InitialTag'].unique()
# Out:
# array(['6/21/19', '10/15/19', '6/24/19', '6/26/19', '5/21/22', '5/25/22',
#        '12/5/22', '6/25/19', '6/22/19', '10/13/19', '5/24/22', '6/21/24',
#        '6/23/19', '10/14/19', '5/20/22', '12/3/22', '1/13/24', '4/29/24'],
#       dtype=object)

# %%
# Convert 'Date_InitialTag' to datetime format and then to 'mmyyyy' format
colony_data['Tag_Date_mmyyyy'] = pd.to_datetime(colony_data['Date_InitialTag']).dt.strftime('%m%Y')
colony_data['Tag_Date_mmyyyy']
# Out:
# /tmp/ipykernel_1111700/981829379.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   colony_data['Tag_Date_mmyyyy'] = pd.to_datetime(colony_data['Date_InitialTag']).dt.strftime('%m%Y')
# ID
# SSID_T1_1     062019
# PAST_T1_2     062019
# SSID_T1_3     062019
# PSTR_T1_4     102019
# SSID_T1_5     062019
#                ...
# OFAV_T6_32    042024
# OANN_T6_33    042024
# OFAV_T6_34    042024
# OFAV_T6_35    042024
# OANN_T6_36    042024
# Name: Tag_Date_mmyyyy, Length: 219, dtype: object

# %%
sample_data
# Out:
#            Month_year Country Location CollectionDate Transect TransectNum  \
# ID
# OFAV_T4_77     122022     BEL      CBC        12/5/22   CURLEW           4
# PAST_T1_2      092023     BEL      CBC        9/25/23   CBC30N           1
# PAST_T1_21     092023     BEL      CBC        9/25/23   CBC30N           1
# SSID_T1_3      092023     BEL      CBC        9/25/23   CBC30N           1
# MCAV_T1_24     092023     BEL      CBC        9/25/23   CBC30N           1
# ...               ...     ...      ...            ...      ...         ...
# OFAV_T4_78     062024     BEL      CBC        6/22/24   CURLEW           4
# OFAV_T4_78     062024     BEL      CBC        6/22/24   CURLEW           4
# MCAV_T4_76     062024     BEL      CBC        6/22/24   CURLEW           4
# MCAV_T4_76     062024     BEL      CBC        6/22/24   CURLEW           4
# MCAV_T4_76     062024     BEL      CBC        6/22/24   CURLEW           4
#
#            OldTagNum NewTagNum Species Time_sampled  ...    Sample_type  \
# ID                                                   ...
# OFAV_T4_77       NaN        77    OFAV          NaN  ...    Core_frozen
# PAST_T1_2        NaN         2    PAST          NaN  ...  Core_RNAlater
# PAST_T1_21       NaN        21    PAST          NaN  ...  Core_RNAlater
# SSID_T1_3        NaN         3    SSID          NaN  ...  Core_RNAlater
# MCAV_T1_24       NaN        24    MCAV          NaN  ...  Core_RNAlater
# ...              ...       ...     ...          ...  ...            ...
# OFAV_T4_78       NaN        78    OFAV         9:24  ...  Core_RNAlater
# OFAV_T4_78       NaN        78    OFAV         9:24  ...         Immune
# MCAV_T4_76       NaN        76    MCAV         9:31  ...    Core_frozen
# MCAV_T4_76       NaN        76    MCAV         9:31  ...  Core_RNAlater
# MCAV_T4_76       NaN        76    MCAV         9:31  ...         Immune
#
#            SampleNum Health_status     Sampling_notes  \
# ID
# OFAV_T4_77        18       Healthy                NaN
# PAST_T1_2        171       Healthy            CLP 90%
# PAST_T1_21       172       Healthy              No CL
# SSID_T1_3        173       Healthy    CLP 80%; DC 20%
# MCAV_T1_24       174       Healthy            CLP 10%
# ...              ...           ...                ...
# OFAV_T4_78      1461       Healthy  sampled from edge
# OFAV_T4_78      1459       Healthy  sampled from edge
# MCAV_T4_76      1463       Healthy  sampled from edge
# MCAV_T4_76      1464       Healthy  sampled from edge
# MCAV_T4_76      1462       Healthy  sampled from edge
#
#            Sample_physical_location Extraction_physical_location  \
# ID
# OFAV_T4_77                      NaN                          NaN
# PAST_T1_2        UML_NARWHAL_R1_B10                          NaN
# PAST_T1_21       UML_NARWHAL_R1_B10                          NaN
# SSID_T1_3        UML_NARWHAL_R1_B10                          NaN
# MCAV_T1_24       UML_NARWHAL_R1_B10                          NaN
# ...                             ...                          ...
# OFAV_T4_78       UML_NARWHAL_R5_B26                          NaN
# OFAV_T4_78                      NaN                          NaN
# MCAV_T4_76                      NaN                          NaN
# MCAV_T4_76       UML_NARWHAL_R5_B26                          NaN
# MCAV_T4_76                      NaN                          NaN
#
#            Date_sequenced Notes Month  Year
# ID
# OFAV_T4_77            NaN   NaN    12  2022
# PAST_T1_2             NaN   NaN    09  2023
# PAST_T1_21            NaN   NaN    09  2023
# SSID_T1_3             NaN   NaN    09  2023
# MCAV_T1_24            NaN   NaN    09  2023
# ...                   ...   ...   ...   ...
# OFAV_T4_78            NaN   NaN    06  2024
# OFAV_T4_78            NaN   NaN    06  2024
# MCAV_T4_76            NaN   NaN    06  2024
# MCAV_T4_76            NaN   NaN    06  2024
# MCAV_T4_76            NaN   NaN    06  2024
#
# [2093 rows x 21 columns]

# %%
sample_data['Sample_type'].unique()
# Out:
# array(['Core_frozen', 'Core_RNAlater', 'Core_EtOH', 'Probiotics',
#        'Immune', 'TEM', nan, 'Syringe'], dtype=object)

# %%
# exclude tem, na, or syringe for now 
# Exclude 'TEM', 'Syringe', or NaN values
filtered_samples = sample_data[
    (sample_data['Sample_type'] != 'TEM') & 
    (sample_data['Sample_type'] != 'Syringe') & 
    (sample_data['Sample_type'].notna())
]

# %%
filtered_samples['Transect'].unique()
# Out:
# array(['CURLEW', 'CBC30N', 'SR30N', 'Curlew', 'Lagoon', 'CBC Lagoon',
#        'Lagoon ', 'BB', 'Hangman ', 'LAGOON'], dtype=object)

# %%
# make all t names consistent 
filtered_samples.loc[(filtered_samples['Transect'].str.contains("Curlew",case=False)),'Transect']='CURLEW'
filtered_samples.loc[(filtered_samples['Transect'].str.contains("Lagoon",case=False)),'Transect']='LAGOON'
filtered_samples.loc[(filtered_samples['Transect'].str.contains("Hangman",case=False)),'Transect']='HANGMAN'
filtered_samples['Transect'].unique()
# Out:
# array(['CURLEW', 'CBC30N', 'SR30N', 'LAGOON', 'BB', 'HANGMAN'],
#       dtype=object)

# %%
# make sorted list of transects 
all_transects = filtered_samples['Transect'].unique()
sorted_transects = sorted(all_transects)

# %%
#make monthyear in chronological order 
filtered_samples['Month_year_datetime'] = pd.to_datetime(filtered_samples['Month_year'], format='%m%Y')

# Sort by the new datetime column
filter_samp_sorted = filtered_samples.sort_values(by='Month_year_datetime')

# Get sorted unique dates in the 'mmyyyy' format
sorted_dates = filter_samp_sorted['Month_year_datetime'].dt.strftime('%m%Y').unique()
sorted_dates
# Out:
# array(['062019', '102019', '052022', '122022', '092023', '112023',
#        '122023', '012024', '022024', '042024', '062024'], dtype=object)

# %%
# still working on this 


# Initialize an empty list to store summary data for each date
summary_data = []

# Iterate through dates
for date in sorted_dates:
    # Filter data for the specific date
    date_data = filtered_samples[filtered_samples['Month_year'] == date]
    # Count tagged corals
    colony_data['
                
                
    # count number of corals sampled 
    num_tagged = len(date_data['NewTagNum'].unique())
        
        # Count UML samples
    num_uml_samples = num_core_samples = transect_data[
        (transect_data['Sample_type'] == 'Core_EtOH') | 
        (transect_data['Sample_type'] == 'Core_RNAlater')
    ].shape[0]
        
        # Count frozen samples
    num_frozen_samples = transect_data[transect_data['Sample_type'] == 'Core_frozen'].shape[0]
        
        # Count immune samples
    num_immune_samples = transect_data[transect_data['Sample_type'] == 'Immune'].shape[0]
        
        # Append the results to summary_data
    summary_data.append({
            'Date': date,
            'num_tagged': num_tagged,
            'num_uml_samples': num_uml_samples,
            'num_tx_samples': num_frozen_samples,
            'num_immune_samples': num_immune_samples
        })

# Convert summary_data into a DataFrame
summary_df = pd.DataFrame(summary_data)

# Display the summary DataFrame
summary_df
# Out:
#       Date  num_tagged  num_uml_samples  num_tx_samples  num_immune_samples
# 0   062019          69               11              11                  11
# 1   102019          20               11              11                  11
# 2   052022          64               11              11                  11
# 3   122022          75               11              11                  11
# 4   092023          68               11              11                  11
# 5   112023          32               11              11                  11
# 6   122023          32               11              11                  11
# 7   012024          55               11              11                  11
# 8   022024          31               11              11                  11
# 9   042024          84               11              11                  11
# 10  062024          32               11              11                  11

# %%
# Initialize an empty list to store summary data for each date
summary_data = []

# Iterate through dates
for date in sorted_dates:
    # Filter data for the specific date
    date_data = filtered_samples[filtered_samples['Month_year'] == date]
    
    # Optionally split by transect
    transects = date_data['Transect'].unique()
    
    for transect in sorted_transects:
        transect_data = date_data[date_data['Transect'] == transect]
        
        # Count tagged corals
        num_tagged = len(transect_data['NewTagNum'].unique())
        
        # Count newly tagged corals by matching 'Tag_Date_mmyyyy' with the current date
        newly_tagged = colony_data[colony_data['Tag_Date_mmyyyy'] == date]
        num_newly_tagged = newly_tagged.shape[0]
        
        # Total tagged
        total_tagged = num_tagged + num_newly_tagged
        
        # Count UML samples
        num_uml_samples = num_core_samples = transect_data[
            (transect_data['Sample_type'] == 'Core_EtOH') | 
            (transect_data['Sample_type'] == 'Core_RNAlater')
        ].shape[0]
        
        # Count frozen samples
        num_frozen_samples = transect_data[transect_data['Sample_type'] == 'Core_frozen'].shape[0]
        
        # Count immune samples
        num_immune_samples = transect_data[transect_data['Sample_type'] == 'Immune'].shape[0]
        
        # Append the results to summary_data
        summary_data.append({
            'Date': date,
            'Transect': transect,
            'num_tagged': num_tagged,
            'num_newly_tagged': num_newly_tagged,
            'num_total_tagged': total_tagged,
            'num_uml_samples': num_uml_samples,
            'num_tx_samples': num_frozen_samples,
            'num_immune_samples': num_immune_samples
        })

# Convert summary_data into a DataFrame
summary_df = pd.DataFrame(summary_data)

# Display the summary DataFrame
summary_df
# Out:
#       Date Transect  num_tagged  num_newly_tagged  num_total_tagged  \
# 0   062019       BB           0                85                85
# 1   062019   CBC30N          24                85               109
# 2   062019   CURLEW           0                85                85
# 3   062019  HANGMAN           0                85                85
# 4   062019   LAGOON          31                85               116
# ..     ...      ...         ...               ...               ...
# 61  062024   CBC30N           6                 1                 7
# 62  062024   CURLEW           6                 1                 7
# 63  062024  HANGMAN           0                 1                 1
# 64  062024   LAGOON          12                 1                13
# 65  062024    SR30N          11                 1                12
#
#     num_uml_samples  num_tx_samples  num_immune_samples
# 0                 0               0                   0
# 1                24              24                   0
# 2                 0               0                   0
# 3                 0               0                   0
# 4                32              32                   0
# ..              ...             ...                 ...
# 61                7               7                   5
# 62                6               6                   6
# 63                0               0                   0
# 64               13              13                  11
# 65               11              11                  11
#
# [66 rows x 8 columns]
