# %% [markdown]
# # Sample Organization and Summary Calculations

# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata')

# %%
sample_data=pd.read_csv('CBC_samples.csv')

# %%
sample_data
# Out:
#       Month_year Country Location CollectionDate Transect  TransectNum  \
# 0         122022     BEL      CBC        12/5/22   CURLEW            4
# 1          92023     BEL      CBC        9/25/23   CBC30N            1
# 2          92023     BEL      CBC        9/25/23   CBC30N            1
# 3          92023     BEL      CBC        9/25/23   CBC30N            1
# 4          92023     BEL      CBC        9/25/23   CBC30N            1
# ...          ...     ...      ...            ...      ...          ...
# 2099       62024     BEL      CBC        6/22/24   CURLEW            4
# 2100       62024     BEL      CBC        6/22/24   CURLEW            4
# 2101       62024     BEL      CBC        6/22/24   CURLEW            4
# 2102       62024     BEL      CBC        6/22/24   CURLEW            4
# 2103       62024     BEL      CBC        6/22/24   CURLEW            4
#
#      OldTagNum NewTagNum Species Time_sampled Time_processed    Sample_type  \
# ...

# %%
colony_data=pd.read_csv('CBC_ColonyData.csv')
colony_data.drop(columns="Unnamed: 0",inplace=True)
colony_data.head()
# Out:
#   Date_InitialTag Transect  TransectNum OldTagNum NewTagNum Species  Meter  \
# 0         6/21/19   CBC30N            1       349         1    SSID    1.5
# 1         6/21/19   CBC30N            1       334         2    PAST    1.4
# 2         6/21/19   CBC30N            1       346         3    SSID    6.3
# 3        10/15/19   CBC30N            1       407         4    PSTR    6.5
# 4         6/24/19   CBC30N            1       394         5    SSID    4.3
#
#    Meters_90 Direction  Size_Class  ...  012024_Condition  012024_Percentage  \
# 0        0.5     right         5.0  ...          Diseased                NaN
# 1        0.1      left         4.0  ...              Dead                NaN
# 2        0.8     right         5.0  ...           Healthy                NaN
# 3        0.5     right         3.0  ...              Dead                NaN
# 4        1.2      left         5.0  ...          Diseased                NaN
#
# ...

# %%
colony_data.columns
# Out:
# Index(['Date_InitialTag', 'Transect', 'TransectNum', 'OldTagNum', 'NewTagNum',
#        'Species', 'Meter', 'Meters_90', 'Direction', 'Size_Class',
#        'MaxDiameter', 'Height', 'Date_DocumentedDisease',
#        'Date_DocumentedMortality', 'Notes_062019', 'Notes_052022',
#        'Notes_092023', 'Notes_112023', 'Notes_122023', 'Notes_012024',
#        'Notes_022024', 'Notes_042024', '062019_Condition', '062019_Percentage',
#        '052022_Condition', '052022_Percentage', '122022_Condition',
#        '092023_Condition', '092023_Percentage', '112023_Condition',
#        '112023_Percentage', '122023_Condition', '122023_Percentage',
#        '012024_Condition', '012024_Percentage', '022024_Condition',
#        '022024_Percentage', '042024_Condition', '042024_Percentage',
#        'checked_colonies', '062024_Condition', '062024_Percentage',
#        'Notes_062024'],
#       dtype='object')

# %% [markdown]
# ### Immune coral sample calculation
# - calculate total num of immune corals & total num of samples (tube labels) needed on immune sampling trip

# %%
# select for immune sample types 
immune_samples=sample_data.loc[(sample_data["Sample_type"]=="Immune"),]
immune_samples.head()
# Out:
#     Month_year Country Location CollectionDate Transect  TransectNum  \
# 51       92023     BEL      CBC        9/25/23   CBC30N            1
# 52       92023     BEL      CBC        9/25/23   CBC30N            1
# 53       92023     BEL      CBC        9/25/23   CBC30N            1
# 54       92023     BEL      CBC        9/25/23   CBC30N            1
# 55       92023     BEL      CBC        9/25/23   CBC30N            1
#
#    OldTagNum NewTagNum Species Time_sampled Time_processed Sample_type  \
# 51       NaN         2    PAST          NaN            NaN      Immune
# 52       NaN        21    PAST          NaN            NaN      Immune
# 53       NaN         3    SSID          NaN            NaN      Immune
# 54       NaN        24    MCAV          NaN            NaN      Immune
# 55       NaN        13    PAST          NaN            NaN      Immune
#
#    SampleNum Health_status   Sampling_notes Tubelabel_species  \
# ...

# %%
immune_samples["Transect"].unique()
# Out:
# array(['CBC30N', 'SR30N', 'Curlew', 'Lagoon', 'CBC Lagoon', 'Lagoon ',
#        'LAGOON', 'CURLEW'], dtype=object)

# %%
Lagoon=(immune_samples["Transect"]=="Lagoon") | (immune_samples["Transect"]=="Lagoon ") | (immune_samples["Transect"]=="CBC Lagoon")

# %%
# make different dfs per transect 
cbc_immune=immune_samples.loc[(immune_samples["Transect"]=="CBC30N"),:]
print(cbc_immune["NewTagNum"].unique())
num_cbc=len(cbc_immune["NewTagNum"].unique())
print("Total # of corals in CBC30N: ",num_cbc)
print("Total # of samples at CBC30N: ", (num_cbc*3))
print("# of labels: ", (num_cbc*3)+4)
# Out:
# ['2' '21' '3' '24' '13' '20' '12' '25']
# Total # of corals in CBC30N:  8
# Total # of samples at CBC30N:  24
# # of labels:  28

# %%
# make different dfs per transect 
sr_immune=immune_samples.loc[(immune_samples["Transect"]=="SR30N"),:]
print(sr_immune["NewTagNum"].unique())
num_SR=len(sr_immune["NewTagNum"].unique())-1
print("Total # of corals in SR30N: ",num_SR) #subtracting 1 since 'Not 51 but adjacent' and '51/not 51' are the same
print("Total # of samples at SR30N: ", (num_SR*3))
print("# of labels: ", (num_SR*3)+4)
# Out:
# ['79' '76' '73' '72' '68' '69' '74' 'Not 51 but adjacent' '63' '57' '60'
#  '55' '51/not 51' '51' '99']
# Total # of corals in SR30N:  14
# Total # of samples at SR30N:  42
# # of labels:  46

# %%
# make different dfs per transect 
lagoon_immune=immune_samples.loc[Lagoon,:]
print(lagoon_immune["NewTagNum"].unique())
num_lag=len(lagoon_immune["NewTagNum"].unique())
print("Total # of corals in Lagoon: ",num_lag)
print("Total # of samples at Lagoon: ", (num_lag*3))
print("# of labels: ", (num_lag*3)+4)
# Out:
# ['39' '20' '66' '38' '14' '34' '33' '10' '21' '6' '5' '2' '70' '66/41']
# Total # of corals in Lagoon:  14
# Total # of samples at Lagoon:  42
# # of labels:  46

# %%
# make different dfs per transect 
curlew_immune=immune_samples.loc[(immune_samples["Transect"]=="Curlew"),:]
print(curlew_immune["NewTagNum"].unique())
num_cur=len(curlew_immune["NewTagNum"].unique())
print("Total # of corals in Curlew: ",num_cur)
print("Total # of samples at Curlew: ", (num_cur*3))
print("# of labels: ", (num_cur*3)+4)
# Out:
# ['28' '98' '79' '76' '78' '30']
# Total # of corals in Curlew:  6
# Total # of samples at Curlew:  18
# # of labels:  22

# %%
print("Total number of corals: ",num_cbc+num_lag+num_SR+num_cur)
print("Total number of samples: ",(num_cbc*3)+(num_lag*3)+(num_SR*3)+(num_cur*3))
# Out:
# Total number of corals:  42
# Total number of samples:  126

# %% [markdown]
# ### Data Cleanup

# %% [markdown]
# #### Format Issues

# %%
# making df a little smaller
cols_drop=["Location","Sample_physical_location","Extraction_physical_location","Time_sampled","Time_processed"]
sample_data.drop(columns=cols_drop,inplace=True)

# %%
# clean up column names
sample_data.columns
# Out:
# Index(['Month_year', 'Country', 'CollectionDate', 'Transect', 'TransectNum',
#        'OldTagNum', 'NewTagNum', 'Species', 'Sample_type', 'SampleNum',
#        'Health_status', 'Sampling_notes', 'Tubelabel_species',
#        'Date_sequenced', 'Notes'],
#       dtype='object')

# %% [raw]
# # remove space from 'Transect '
# sample_data.rename(columns={'Transect ': 'Transect'}, inplace=True)
# # replace space in 'Health status' with _
# sample_data.rename(columns={'Health status': 'Health_status'}, inplace=True)
# sample_data.columns

# %%
# convert dates to str
sample_data['Month_year'] = sample_data['Month_year'].astype(str)
# remove the decimal point
sample_data['Month_year'] = sample_data['Month_year'].str.replace('.0', '')

# add leading zeros where necessary
sample_data['Month_year'] = sample_data['Month_year'].str.pad(width=6, side='left', fillchar='0')
sample_data['Month_year']
# Out:
# 0       122022
# 1       092023
# 2       092023
# 3       092023
# 4       092023
#          ...
# 1988    122022
# 1989    122022
# 1990    052022
# 1991    052022
# 1992    102019
# Name: Month_year, Length: 1993, dtype: object

# %%
# Extract month and year to make separate columns 
sample_data.loc[:,'Month'] = sample_data.loc[:,'Month_year'].str[0:2]
sample_data.loc[:,'Year'] = sample_data.loc[:,'Month_year'].str[2:]

# %% [raw]
# # make transect number regular integer??? (drop decimal)
# #first fix nas
# sample_data[sample_data['TransectNum'].isna()]

# %% [raw]
# #drop rows where all entries are NA
# sample_data.drop(index=sample_data.iloc[1152:1161,:].index.tolist(),axis=0, inplace=True)

# %% [raw]
# #add transectnum to curlew
# curlew_rows=sample_data['Transect'].str.contains("curlew", case=False)
# sample_data.loc[curlew_rows,"TransectNum"]="4"

# %% [raw]
# #change transect num values from decimals (float values)
# sample_data["TransectNum"]=sample_data["TransectNum"].astype(int)

# %%
sample_data["TransectNum"].unique()
# Out:
# array([4, 1, 2, 3, 5, 6])

# %% [markdown]
# #### Data Issues

# %% [markdown]
# ##### Na in monthyear
# - already run - don't run again

# %% [raw]
# nan_values = sample_data[sample_data['Month_year'].str.contains("nan", na=False)]
# print(nan_values.head(2))
# nan_values.shape
# # don't know how there's no more info on these samples...may need to go through commit history and figure out what these are

# %% [raw]
# # delete these for now: na rows in MonthYear
# sample_data = sample_data[~sample_data['Month_year'].str.contains("nan", na=False)]
# # Reset index if needed
# sample_data.reset_index(drop=True, inplace=True)
# sample_data

# %% [raw]
# # confirming it dropped the right amount of rows to match nan_values
# 1995-9

# %%
# convert columns to datetimes 
sample_data.loc[:,'Month_year']=pd.to_datetime(sample_data['Month_year'], format = '%m%Y').dt.date
# convert month numbers to month abbreviations 
sample_data.loc[:,'Month']=pd.to_datetime(sample_data['Month'], format = '%m').dt.month_name().str.slice(stop=3)

# %% [markdown]
# ##### Too many entries in Health_status

# %%
print(sample_data['Health_status'].unique())
# remove "missing" or non sampled corals from sample sheet 

# for now, making ONLY options Healthy, Diseased_Tissue, or Diseased_Margin
    # can go back and add clp or clb if we need to?
# Out:
# ['Healthy' 'Diseased_Margin' 'Diseased_Tissue' nan 'HealthyNot_Sampled'
#  'HealthyTissue' 'CLP 100%' 'MISS_SAMPLE' 'MiSSING' 'MISSING'
#  'Diseased_tissue' 'Diseased_margin' 'Disease']

# %% [markdown]
# ###### first look at nan values

# %%
nas=sample_data['Health_status'].isna()
na_health=sample_data[nas]
na_health.loc[:,("Month", "Year", "Health_status", "NewTagNum", "SampleNum", "Sample_type", "Sampling_notes")]
# Look at year by year 
na_health_2019=na_health["Year"]=='2019'
na_health[na_health_2019]
# Out:
# Empty DataFrame
# Columns: [Month_year, Country, CollectionDate, Transect, TransectNum, OldTagNum, NewTagNum, Species, Sample_type, SampleNum, Health_status, Sampling_notes, Tubelabel_species, Date_sequenced, Notes, Month, Year]
# Index: []

# %%
# look at 2022

na_health_2022=na_health["Year"]=='2022'
na_health[na_health_2022]
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 566   2022-05-01     BEL        5/22/22    SR30N            2       347
# 640   2022-05-01     BEL        5/21/22   CBC30N            1       359
# 1990  2022-05-01     BEL        5/20/22  Lagoon             3       NaN
#
#      NewTagNum Species Sample_type SampleNum Health_status Sampling_notes  \
# 566        347    PAST         NaN       NaN           NaN            NaN
# 640         15    MCAV         TEM        11           NaN            NaN
# 1990        AS    PAST   Core_EtOH        17           NaN            NaN
#
#               Tubelabel_species Date_sequenced  \
# 566     052022_BEL_CBC_T2__PAST            NaN
# 640   052022_BEL_CBC_T1_11_MCAV            NaN
# 1990  052022_BEL_CBC_T3_17_PAST            NaN
#
#                                      Notes Month  Year
# 566                                    NaN   May  2022
# 640                                    NaN   May  2022
# ...

# %%
# look at SampleNum 11 (colony #15) in colony data to see if health status is there
# and tag# 347 PAST with all na entries

# %%
# look at SampleNum 11 (colony #15) in colony data to see if health status is there

# TagNum 15,MCAV, SampleNum 11, cbc30n
tag_15=(colony_data['NewTagNum']=="15") & (colony_data['Transect']=="CBC30N")
condition_cols=colony_data.columns.str.contains("Condition")
colony_data.loc[tag_15,condition_cols]
# CONDITION = diseased 
## CHANGE to diseased_tissue
# Out:
#    062019_Condition 052022_Condition 122022_Condition 092023_Condition  \
# 14          Healthy         Diseased             Dead             Dead
#
#    112023_Condition 122023_Condition 012024_Condition 022024_Condition  \
# 14             Dead             Dead             Dead             Dead
#
#    042024_Condition
# 14              NaN

# %%
# disease_tissue for TEM 
sample_data[(sample_data["NewTagNum"]=="15") & (sample_data["Year"]=="2022") & (sample_data["Transect"]=="CBC30N")]
# Note for TEM samplenum: just leave as is and filter later based on sample type
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 640  2022-05-01     BEL        5/21/22   CBC30N            1       359
# 697  2022-05-01     BEL        5/21/22   CBC30N            1       359
# 699  2022-05-01     BEL        5/21/22   CBC30N            1       359
# 731  2022-05-01     BEL        5/21/22   CBC30N            1       359
# 733  2022-05-01     BEL        5/21/22   CBC30N            1       359
#
#     NewTagNum Species  Sample_type SampleNum    Health_status Sampling_notes  \
# 640        15    MCAV          TEM        11              NaN            NaN
# 697        15    MCAV    Core_EtOH        40  Diseased_Margin            NaN
# 699        15    MCAV  Core_frozen        42  Diseased_Margin            NaN
# 731        15    MCAV    Core_EtOH        70  Diseased_Tissue            NaN
# 733        15    MCAV  Core_frozen        73  Diseased_Tissue            NaN
#
#              Tubelabel_species Date_sequenced  \
# ...

# %%
# change Health status for TEM sample to Diseased_Tissue
sample_data.loc[640, "Health_status"] = "Diseased_Tissue"
sample_data.loc[640, "Health_status"]
# Out:
# 'Diseased_Tissue'

# %%
# look at TagNum 347 PAST in colony data to find more info

# oldtagnum = 347, sr30n
tag_347=(colony_data['OldTagNum']=="347") & (colony_data['Transect']=="SR30N")
condition_cols=colony_data.columns.str.contains("Condition")
colony_data.loc[tag_347,condition_cols]
# Colony was not found after 2019
# Out:
#    062019_Condition 052022_Condition 122022_Condition 092023_Condition  \
# 76          Healthy      Not_visited      Not_visited      Not_visited
#
#    112023_Condition 122023_Condition 012024_Condition 022024_Condition  \
# 76      Not_visited      Not_visited      Not_visited      Not_visited
#
#    042024_Condition
# 76      Not_visited

# %%
sample_tag_347=(sample_data['OldTagNum']=="347") & (sample_data['Transect']=="SR30N")
sample_data[sample_tag_347]
#only samples are from 2019..so remove 2022 entry from sample sheet (and copy oldtagnum to newtagnum)
# it wasn't sampled in may 2022 so deleting... 
# AND colony data was changed to reflect it not being found again
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 566  2022-05-01     BEL        5/22/22    SR30N            2       347
# 888  2019-06-01     BEL        6/25/19    SR30N            2       347
# 901  2019-06-01     BEL        6/25/19    SR30N            2       347
# 902  2019-06-01     BEL        6/25/19    SR30N            2       347
#
#     NewTagNum Species  Sample_type SampleNum Health_status Sampling_notes  \
# 566       347    PAST          NaN       NaN           NaN            NaN
# 888       347    PAST      Syringe       110       Healthy    tag cut off
# 901       347    PAST    Core_EtOH        20       Healthy    tag cut off
# 902       347    PAST  Core_frozen       20N       Healthy    tag cut off
#
#               Tubelabel_species Date_sequenced Notes Month  Year
# 566     052022_BEL_CBC_T2__PAST            NaN   NaN   May  2022
# 888  062019_BEL_CBC_T2_110_PAST            NaN   NaN   Jun  2019
# ...

# %%
# remove entry of PAST, tag 347, SR30N in 2022 since no sample was take
sample_data.drop(index=566,inplace=True)

# %%
# look at nan in 2023

nas=sample_data['Health_status'].isna()
na_health=sample_data[nas]
na_health.loc[:,("Month", "Year", "Health_status", "NewTagNum", "SampleNum", "Sample_type", "Sampling_notes")]
# Look at year by year 
na_health_2023=na_health["Year"]=='2023'
na_health[na_health_2023]
# Out:
#     Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 85  2023-09-01     BEL        9/26/23    SR30N            2       NaN
#
#    NewTagNum Species    Sample_type SampleNum Health_status Sampling_notes  \
# 85        32    PSTR  Core_RNAlater       197           NaN       CLP 100%
#
#              Tubelabel_species Date_sequenced Notes Month  Year
# 85  092023_BEL_CBC_T2_197_PSTR            NaN   NaN   Sep  2023

# %%
# look at other samples from that coral at that date 
sample_data[(sample_data["NewTagNum"]=="32") & (sample_data["Transect"]=="SR30N") & (sample_data["Year"]=="2023")]
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 85   2023-09-01     BEL        9/26/23    SR30N            2       NaN
# 197  2023-09-01     BEL        9/26/23    SR30N            2       NaN
#
#     NewTagNum Species    Sample_type SampleNum Health_status Sampling_notes  \
# 85         32    PSTR  Core_RNAlater       197           NaN       CLP 100%
# 197        32    PSTR    Core_frozen       260       Healthy       CLP 100%
#
#               Tubelabel_species Date_sequenced Notes Month  Year
# 85   092023_BEL_CBC_T2_197_PSTR            NaN   NaN   Sep  2023
# 197                         NaN            NaN   NaN   Sep  2023

# %%
# change health status to healthy for samplenum #197
sample_data.loc[85, "Health_status"] = "Healthy"

# %%
# look at nan in 2024

nas=sample_data['Health_status'].isna()
na_health=sample_data[nas]
na_health.loc[:,("Month", "Year", "Health_status", "NewTagNum", "SampleNum", "Sample_type", "Sampling_notes")]
# Look at year by year 
na_health_2024=na_health["Year"]=='2024'
na_health[na_health_2024]

# check with colony data
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1382  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1383  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1384  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1385  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1386  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# ...          ...     ...            ...      ...          ...       ...
# 1532  2024-01-01     BEL        1/12/24    SR30N            2       NaN
# 1533  2024-01-01     BEL        1/12/24    SR30N            2       NaN
# 1534  2024-01-01     BEL        1/12/24    SR30N            2       NaN
# 1535  2024-01-01     BEL        1/12/24    SR30N            2       NaN
# 1536  2024-01-01     BEL        1/12/24    SR30N            2       NaN
#
#      NewTagNum Species    Sample_type SampleNum Health_status Sampling_notes  \
# ...

# %%
# based on colony data, all jan 2024 BB colonies are healthy
conditions=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="BB")
sample_data.loc[conditions, 'Health_status'] = "Healthy"

# %%
sample_data[(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="BB")]
# Out:
# Empty DataFrame
# Columns: [Month_year, Country, CollectionDate, Transect, TransectNum, OldTagNum, NewTagNum, Species, Sample_type, SampleNum, Health_status, Sampling_notes, Tubelabel_species, Date_sequenced, Notes, Month, Year]
# Index: []

# %%
# check next transect - CBC30N
sample_data[(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="CBC30N")]
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1382  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1383  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1384  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1385  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1386  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1387  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1388  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1389  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1390  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1391  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1392  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# 1393  2024-01-01     BEL        1/10/24   CBC30N            1       NaN
# ...

# %%
# incorporating bleached/paled tissue/margin into conditions

# %%
# colony 3 SSID - can't find pic from 01/2024, but notes and pics show almost complete paling -> bleach in dates surrounding, calling paled_margin
tag_3=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="CBC30N") & (sample_data["NewTagNum"]=="3")
sample_data.loc[tag_3,"Health_status"] = "PALED_MARGIN"

# %%
# rest are healthy: 24, 25, 12, 21 (for now)
cbc_healthy=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="CBC30N")
sample_data[cbc_healthy]
sample_data.loc[cbc_healthy,"Health_status"] = "HEALTHY"

# %%
# check next transect - SR30N
sample_data[(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N")].sort_values(by="NewTagNum")
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1536  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1534  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1535  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1533  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1532  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1531  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1524  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1523  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1522  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1527  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1526  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# 1525  2024-01-01     BEL        1/12/24    SR30N          2.0       NaN
# ...

# %%
# go through pics, colonydata, samplingnotes to determine health status of each colony's samples

# change tag 51 to bleached margin
tag_51=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N") & (sample_data["NewTagNum"]=="51")
sample_data.loc[tag_51,"Health_status"]="BLEACHED_MARGIN"

# %%
# 55 - labelled as healthy but looks paled to me

# %%
# 72 bleached margin 
tag_72=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N") & (sample_data["NewTagNum"]=="72")
sample_data.loc[tag_72,"Health_status"]="BLEACHED_MARGIN"

# %%
# 73 bleached tissue for all but immune (bleached margin)
tag_73=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N") & (sample_data["NewTagNum"]=="73") & (sample_data["Sample_type"]!="Immune")
sample_data.loc[tag_73,"Health_status"]="BLEACHED_TISSUE"
tag_73_immune=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N") & (sample_data["NewTagNum"]=="73") & (sample_data["Sample_type"]=="Immune")
sample_data.loc[tag_73_immune,"Health_status"]="BLEACHED_MARGIN"

# %%
# change statuses to healthy ...51, 72, and 73 colonies labelled as clb or clp
# rest are healthy: 57, 60, 63, 68, 69, 76, 79
sr_conditions=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="SR30N")
sample_data.loc[sr_conditions,"Health_status"]="Healthy"

# %%
# check next transect - Lagoon
sample_data[(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="Lagoon ")].sort_values(by="NewTagNum")
# need to get rid of space in Lagoon also
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1421  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1422  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1423  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1426  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1425  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1424  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1412  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1413  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1414  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1415  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1416  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# 1417  2024-01-01     BEL        1/10/24  Lagoon           3.0       NaN
# ...

# %%
# all are healthy
lagoon_conditions=(sample_data['Health_status'].isna()) & (sample_data["Transect"]=="Lagoon ")
sample_data.loc[lagoon_conditions,"Health_status"]="Healthy"

# %%
# confirm there's no more NAs left
sample_data[sample_data['Health_status'].isna()]
# Out:
# Empty DataFrame
# Columns: [Month_year, Country, CollectionDate, Transect, TransectNum, OldTagNum, NewTagNum, Species, Sample_type, SampleNum, Health_status, Sampling_notes, Tubelabel_species, Date_sequenced, Notes, Month, Year]
# Index: []

# %% [markdown]
# ###### Investigate "missing" samples

# %%
sample_data[sample_data.loc[:,'Health_status'].str.contains("miss",case=False)]
# samples were not taken at that time?
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 565  2022-05-01     BEL        5/22/22    SR30N          2.0       337
# 741  2022-05-01     BEL        5/20/22   Lagoon          3.0        21
# 742  2022-05-01     BEL        5/20/22   Lagoon          3.0       358
#
#     NewTagNum Species Sample_type SampleNum Health_status Sampling_notes  \
# 565        53    MCAV         NaN       NaN   MISS_SAMPLE            NaN
# 741         7    PAST         NaN       NaN       MiSSING  Missed sample
# 742        13    PAST         NaN       NaN       MISSING            NaN
#
#            Tubelabel_species Date_sequenced Notes Month  Year
# 565  052022_BEL_CBC_T2__MCAV            NaN   NaN   May  2022
# 741  052022_BEL_CBC_T3__PAST            NaN   NaN   May  2022
# 742  052022_BEL_CBC_T3__PAST            NaN   NaN   May  2022

# %%
sample_data[(sample_data["NewTagNum"]=="53") & (sample_data["Transect"]=="SR30N")]
# sample was just not taken at that time point, deleting entry
sample_data.drop(index=565,inplace=True)
# Out:
# /tmp/ipykernel_3838846/88251778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.drop(index=565,inplace=True)

# %%
sample_data[(sample_data["NewTagNum"]=="7") & (sample_data["Transect"]=="Lagoon")]
# sample was just not taken at that time point, deleting entry
sample_data.drop(index=741,inplace=True)
# Out:
# /tmp/ipykernel_3838846/508073652.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.drop(index=741,inplace=True)

# %%
sample_data[(sample_data["NewTagNum"]=="13") & (sample_data["Transect"]=="Lagoon")]
# sample was just not taken at that time point, deleting entry
sample_data.drop(index=742,inplace=True)
# I don't think this coral was ever visited again...
# Out:
# /tmp/ipykernel_3838846/3146511017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.drop(index=742,inplace=True)

# %%
sample_data[sample_data['Health_status']=="HealthyNot_Sampled"]
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 475  2022-12-01     BEL        12/2/22   CBC30N          1.0       NaN
#
#     NewTagNum Species  Sample_type SampleNum       Health_status  \
# 475         5    SSID  Core_frozen       NaN  HealthyNot_Sampled
#
#     Sampling_notes        Tubelabel_species Date_sequenced Notes Month  Year
# 475            NaN  122022_BEL_CBC_T1__SSID            NaN   NaN   Dec  2022

# %%
sample_data[(sample_data["NewTagNum"]=="5") & (sample_data["Transect"]=="CBC30N")]
# sample was just not taken at that time point, deleting entry
sample_data.drop(index=475,inplace=True)
# Out:
# /tmp/ipykernel_3838846/2058430068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.drop(index=475,inplace=True)

# %% [markdown]
# ###### Health status as just "disease" - change to diseased_tissue or diseased_margin

# %%
sample_data[sample_data['Health_status']=="Disease"]
# tag 19 - probably Disease_margin since there was so little healthy tissue left
# Out:
#       Month_year Country CollectionDate    Transect  TransectNum OldTagNum  \
# 1649  2024-04-01  Belize        4/25/24      CBC30N          1.0       NaN
# 1716  2024-04-01  Belize        4/25/24  CBC Lagoon          3.0       NaN
# 1717  2024-04-01  Belize        4/25/24  CBC Lagoon          3.0       NaN
#
#      NewTagNum Species    Sample_type SampleNum Health_status  \
# 1649         3    SSID         Immune      1067       Disease
# 1716        19    SSID    Core_frozen       967       Disease
# 1717        19    SSID  Core_RNAlater      1011       Disease
#
#                       Sampling_notes Tubelabel_species Date_sequenced Notes  \
# 1649                 40% CTL, 10% DC               NaN            NaN   NaN
# 1716  95% old mort, 95% DC, webbing                NaN            NaN   NaN
# 1717  95% old mort, 95% DC, webbing                NaN            NaN   NaN
#
#      Month  Year
# 1649   Apr  2024
# 1716   Apr  2024
# 1717   Apr  2024

# %%
# tag 19 - Disease_margin since there was so little healthy tissue left (looked at pics)
sample_data.loc[1716:1717,"Health_status"]="Diseased_Tissue"

# %%
conditions=(sample_data['NewTagNum']=="3") & (sample_data['Year']=="2024") & (sample_data['Transect']=="CBC30N")
sample_data[conditions]
# For immune sample, should be coded as diseased_tissue
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1382  2024-01-01     BEL        1/10/24   CBC30N          1.0       NaN
# 1383  2024-01-01     BEL        1/10/24   CBC30N          1.0       NaN
# 1384  2024-01-01     BEL        1/10/24   CBC30N          1.0       NaN
# 1539  2024-02-01  Belize        2/23/24   CBC30N          1.0       NaN
# 1540  2024-02-01  Belize        2/23/24   CBC30N          1.0       NaN
# 1541  2024-02-01  Belize        2/23/24   CBC30N          1.0       NaN
# 1645  2024-04-01  Belize        4/25/24   CBC30N          1.0       NaN
# 1646  2024-04-01  Belize        4/25/24   CBC30N          1.0       NaN
# 1647  2024-04-01  Belize        4/25/24   CBC30N          1.0       NaN
# 1648  2024-04-01  Belize        4/25/24   CBC30N          1.0       NaN
# 1649  2024-04-01  Belize        4/25/24   CBC30N          1.0       NaN
#
#      NewTagNum Species    Sample_type SampleNum    Health_status  \
# ...

# %%
# change immune sample, colony 3 health status to Diseased_Tissue
sample_data.loc[1649,"Health_status"]="Diseased_Tissue"

# %% [markdown]
# ###### Dont know what to do with this right now

# %%
sample_data[sample_data['Health_status']=='CLP 100%']
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 298  2023-09-01     BEL        9/27/23   Lagoon          3.0       NaN
#
#     NewTagNum Species Sample_type SampleNum Health_status Sampling_notes  \
# 298        70    PSTR      Immune       269      CLP 100%        Healthy
#
#           Tubelabel_species Date_sequenced            Notes Month  Year
# 298  09_2023_BEL-CBC_T3-269            NaN   Crumbly sample   Sep  2023

# %% [markdown]
# ###### Fixing capitalization issues - changing to snake case

# %%
sample_data['Health_status'] = sample_data['Health_status'].str.replace(r'(?i)Diseased_margin', 'diseased_margin', regex=True)
# Out:
# /tmp/ipykernel_3838846/1236047759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data['Health_status'] = sample_data['Health_status'].str.replace(r'(?i)Diseased_margin', 'diseased_margin', regex=True)

# %%
sample_data['Health_status'] = sample_data['Health_status'].str.replace(r'(?i)Diseased_tissue', 'diseased_tissue', regex=True)
sample_data['Health_status'] = sample_data['Health_status'].str.replace('Healthy', 'healthy')
sample_data['Health_status'] = sample_data['Health_status'].str.replace(r'(?i)HealthyTissue', 'healthy', regex=True)
# Out:
# /tmp/ipykernel_3838846/1239169331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data['Health_status'] = sample_data['Health_status'].str.replace(r'(?i)Diseased_tissue', 'diseased_tissue', regex=True)
# /tmp/ipykernel_3838846/1239169331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data['Health_status'] = sample_data['Health_status'].str.replace('Healthy', 'healthy')
# /tmp/ipykernel_3838846/1239169331.py:3: SettingWithCopyWarning:
# ...

# %%
sample_data['Health_status'].unique()
# Out:
# array(['healthy', 'diseased_margin', 'diseased_tissue', 'CLP 100%'],
#       dtype=object)

# %%
# why are there NAs in sampleNum?? if the sample wasn't taken why was it added?
sample_data[sample_data['SampleNum'].isna()]
# Out:
#       Month_year Country Location CollectionDate Transect  TransectNum  \
# 475   2022-12-01     BEL      CBC        12/2/22   CBC30N          1.0
# 565   2022-05-01     BEL      CBC        5/22/22    SR30N          2.0
# 566   2022-05-01     BEL      CBC        5/22/22    SR30N          2.0
# 741   2022-05-01     BEL      CBC        5/20/22   Lagoon          3.0
# 742   2022-05-01     BEL      CBC        5/20/22   Lagoon          3.0
# 812   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 813   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 814   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 815   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 816   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 817   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# 818   2019-10-01     BEL      CBC       10/15/19   CBC30N          1.0
# ...

# %%
sample_data.dropna(subset=["SampleNum"], inplace=True)

# %%
sample_data[sample_data['NewTagNum'].isna()]
# removing 'not sampled' entry

# %%
# removing 'not sampled' entry 
delete=sample_data[sample_data["Sampling_notes"]=="NOT SAMPLED"].index
sample_data.drop(index=delete,inplace=True)
#sample_data.drop(sample_data["Sampling_notes"]=="NOT SAMPLED")

# %%
# make all "disease tissue" entries uniform
#disease_status=sample_data['Health_status'].str.contains("disease",case=False)
#sample_data[disease_status]

# %%
diseased=sample_data['Health_status'].str.contains("disease",case=False)
print(diseased.sum())
#sample_data[diseased]
# Out:
# 409

# %%
# make all species names uniform 
species_list=sample_data['Species'].unique()
print(species_list)
# Out:
# ['OFAV' 'PAST' 'SSID' 'MCAV' 'PSTR' 'OANN' 'DLAB' 'CNAT' 'DL' 'OANN/OFAV?'
#  'MMEA' 'OFAV/OANN' 'PAST ']

# %%
# Change OFAV/OANN variations to ORBI
sample_data.loc[:,'Species']=sample_data['Species'].str.replace('OANN/OFAV?',"ORBI")
sample_data.loc[:,'Species']=sample_data['Species'].str.replace('OFAV/OANN',"ORBI")
# Fix space in PAST
sample_data.loc[:,'Species']=sample_data['Species'].str.replace('PAST ',"PAST")
sample_data['Species'].unique()
# Out:
# array(['OFAV', 'PAST', 'SSID', 'MCAV', 'PSTR', 'OANN', 'DLAB', 'CNAT',
#        'DL', 'ORBI', 'MMEA'], dtype=object)

# %%
DL=sample_data['Species']=='DL'
sample_data[DL]
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 484  2022-12-01     BEL        12/2/22   CBC30N          1.0       NaN
# 509  2022-12-01     BEL        12/2/22   CBC30N          1.0       NaN
#
#     NewTagNum Species Time_sampled Time_processed  Sample_type SampleNum  \
# 484        35      DL          NaN            NaN  Core_frozen       108
# 509        35      DL          NaN            NaN    Core_EtOH       154
#
#     Health_status Sampling_notes         Tubelabel_species Date_sequenced  \
# 484       Healthy            NaN  122022_BEL_CBC_T1_108_DL            NaN
# 509       Healthy            NaN  122022_BEL_CBC_T1_154_DL            NaN
#
#     Notes Month  Year
# 484   NaN   Dec  2022
# 509   NaN   Dec  2022

# %%
# Replace values using regular expressions
sample_data['Species'] = sample_data['Species'].replace('\\bDL\\b', 'DLAB', regex=True)
# Out:
# /tmp/ipykernel_3170559/1020722542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data['Species'] = sample_data['Species'].replace('\\bDL\\b', 'DLAB', regex=True)

# %%
# Check that changes worked
species_list=sample_data['Species'].unique()
print(species_list)
# Out:
# ['OFAV' 'PAST' 'SSID' 'MCAV' 'PSTR' 'OANN' 'DLAB' 'CNAT' 'ORBI' 'MMEA']

# %%
# investigate weird ones
#entries_to_ignore= "

# %%
# load colony data to figure out health statuses of these samples

# %%
# Out:
#   Date_InitialTag Transect  TransectNum OldTagNum NewTagNum Species  Meter  \
# 0         6/21/19   CBC30N            1       349         1    SSID    1.5
# 1         6/21/19   CBC30N            1       334         2    PAST    1.4
# 2         6/21/19   CBC30N            1       346         3    SSID    6.3
# 3        10/15/19   CBC30N            1       407         4    PSTR    6.5
# 4         6/24/19   CBC30N            1       394         5    SSID    4.3
#
#    Meters_90 Direction  Size_Class  ... 112023_Percentage  122023_Condition  \
# 0        0.5     right         5.0  ...               NaN          Diseased
# 1        0.1      left         4.0  ...              100%               CLB
# 2        0.8     right         5.0  ...            5%,95%               CLP
# 3        0.5     right         3.0  ...               NaN              Dead
# 4        1.2      left         5.0  ...               NaN          Diseased
#
# ...

# %%
# determining "DL" species 
tag_35=colony_data['NewTagNum']=='35'
colony_data[tag_35]
# think its just supposed to be dlab
# Out:
#     Date_InitialTag Transect  TransectNum OldTagNum NewTagNum Species  Meter  \
# 25          5/25/22   CBC30N            1        35        35    DLAB   14.5
# 115         6/23/19   Lagoon            3        29        35    MMEA   38.5
# 182         1/13/24       BB            5       NaN        35    OFAV    2.3
# 200         4/29/24  HANGMAN            6       NaN        35    OFAV   30.1
#
#      Meters_90 Direction  Size_Class  ... 112023_Percentage  122023_Condition  \
# 25         0.8      left         NaN  ...               NaN           Healthy
# 115        3.0     right         2.0  ...               NaN              Dead
# 182        4.5         R         NaN  ...               NaN               NaN
# 200        1.4         R         NaN  ...               NaN               NaN
#
#      122023_Percentage 012024_Condition 012024_Percentage 022024_Condition  \
# 25                 NaN          Healthy               NaN          Healthy
# ...

# %% [markdown]
# ## Summary Stats

# %%
# Goal: make summary df that shows how many samples were taken each year for each species - shows sum of sample types too

# %% [markdown]
# ### 2019

# %%
# filter for 2019 samples
s2019 = sample_data["Year"]=='2019'
samples_2019=sample_data[s2019]

# %%
print(sample_data['Health_status'].unique())
# Out:
# ['Healthy' 'Diseased_Margin' 'Diseased_Tissue' nan 'CLP 100%'
#  'HealthyNot_Sampled' 'HealthyTissue' 'MISS_SAMPLE' 'MiSSING' 'MISSING'
#  'Diseased_tissue' 'Diseased_margin' 'Disease']

# %%
healthy=samples_2019['Health_status']=="Healthy"
print("Total # of healthy samples in 2019:",healthy.sum())
# Out:
# Total # of healthy samples in 2019: 340

# %%
healthy_2019=samples_2019[healthy]
print(healthy_2019['OldTagNum'].unique())
healthy_2019['OldTagNum'].value_counts(ascending=True)
# Out:
# ['407' '413' '418' '417' '404' '422' '419' '408' '409' '412' '415' '411'
#  '423' '426' '414' '421' '406' '400' '427' '420' '403' '359' '389' '393'
#  '36' '34' '392' '41' '347' '387' '62' '56' '91' '47' '396' '395' '397'
#  '391' '388' '382' '384' '390' '381' '386' '385' '383' '380' '394' '367'
#  '304' '369' '374' '378' '21' '12flag' '370' '327' '358' '365' '300' '301'
#  '363' '307' '316' '364' '321' '345' '314' '22' '23' '24' '25' '373' '28'
#  '27' '29' '353' '350' '361' '379' '305' '356' '328' '343' '317' '325'
#  '320' '311' '337' '355' '333' '334' '329' '335' '357' '303' '349' '346'
#  '342' '354' '339' '341' '352' '348' '344' '330' '336']
# OldTagNum
# 341       1
# 409       2
# 415       2
# 412       2
# 423       2
#          ..
# 369       4
# 374       4
# 407       4
# 21        4
# 12flag    4
# Name: count, Length: 107, dtype: int64

# %%
print("Total # of healthy sampled COLONIES in 2019:",healthy_2019['OldTagNum'].value_counts().shape)
# Out:
# Total # of healthy sampled COLONIES in 2019: (107,)

# %%
# for each species in 2019, calculate total number of active tagged colonies and total num of samples taken

# %%
healthy_2019["Health_status"].unique()
# Out:
# array(['Healthy'], dtype=object)

# %%
# create dictionary with necessary columns 
d={"Species":[],"Health_status":[], "Tagged_colonies":[], "Num_samples":[]}
# loop thru each species in healthy 2019 df
species_list=healthy_2019['Species'].unique()
statuses=healthy_2019["Health_status"].unique()

for specie in species_list:
    # add specie name to 'species' col
    d["Species"].append(specie)
    
    # determine num of tagged colonies in each health status in each species
    # create species-specific df
    sp=healthy_2019['Species']==specie
    sp_df=healthy_2019[sp]
        
    for status in statuses:
        d["Health_status"].append(status)
        # create new df with each health status within each species 
        status_sp=sp_df["Health_status"]==status
        status_sp_df=sp_df[status_sp]
        
        colonies=status_sp_df["OldTagNum"].nunique()

        #add num of tagged colonies to dict
        d["Tagged_colonies"].append(colonies)

        #determine num of samples in each health status in each species
        samples=status_sp_df["SampleNum"].nunique()

        #add to dict
        d["Num_samples"].append(samples)
#convert d to df
d
SampleCounts_healthy2019=pd.DataFrame.from_dict(d)
SampleCounts_healthy2019
# Out:
#   Species Health_status  Tagged_colonies  Num_samples
# 0    PSTR       Healthy               21           39
# 1    MCAV       Healthy               24           56
# 2    PAST       Healthy               20           52
# 3    SSID       Healthy               28           60
# 4    MMEA       Healthy               13           34
# 5    CNAT       Healthy                1            3

# %%
# matches Sarah's sheet: https://docs.google.com/spreadsheets/d/16jlkSd8hLOTxRQoi_4W6WPUSoKN-sNtz1ChALbn6HhU/edit#gid=0
# can we add in health status too? should we make one massive table for all years and such or split it up?

# %%
# there are still lots of issues with the data:
# - weird health statuses 
# - na values in important places like tagnum or date collected

# %%
sample_data.columns
# Out:
# Index(['Month_year', 'Country', 'CollectionDate', 'Transect', 'TransectNum',
#        'OldTagNum', 'NewTagNum', 'Species', 'Time_sampled', 'Time_processed',
#        'Sample_type', 'SampleNum', 'Health_status', 'Sampling_notes',
#        'Tubelabel_species', 'Date_sequenced', 'Notes', 'Month', 'Year'],
#       dtype='object')

# %%
sample_data["NewTagNum"].unique()
# Out:
# array(['77', '2', '21', '3', '24', '13', '20', '12', '25', '7', '19',
#        '27', '35', '1', '23', '5', '22', '9', '11', '16', '17', '79',
#        '76', '73', '72', '68', '69', '74', 'Not 51 but adjacent', '63',
#        '57', '55', '60', '54', '71', '75', '66', '67', '80', '30', '52',
#        '32', '56', '31', '59', '78', '94', '93', '100', '96', '95', '92',
#        '98', '97', '43', '28', '99', '53', '64', '29', '39', '38', '14',
#        '6', '8', '10', '33', '34', '4', '18', '36', '70', '65', 'NOTAG',
#        '15', '37', '26', '41', nan, '58', '62', '51', '61', 'Na',
#        '51/not 51', '50', '49', '48', '47', '46', '45', '44', '42', '40',
#        '66/41'], dtype=object)

# %%
# repeat process for each year...try to include year in dictionary ???
# 2022:
d_22={"Species":[],"Health_status":[], "Tagged_colonies":[], "Num_samples":[]}
#create 2022 df
s2022 = sample_data["Year"]=='2022'
samples_2022=sample_data[s2022]

# create lists of species and health statuses
species_list=sample_data['Species'].unique()
statuses=sample_data["Health_status"].unique()

samples_2022
print(species_list)
# Out:
# ['OFAV' 'PAST' 'SSID' 'MCAV' 'PSTR' 'OANN' 'DLAB' 'CNAT' 'DL' 'OANN/OFAV?'
#  'MMEA' 'OFAV/OANN' 'PAST ']

# %%
# loop thru each species in healthy 2019 df
for specie in species_list:
# add specie name to 'species' col
    d_22["Species"].append(specie)

    # determine num of tagged colonies in each health status in each species
    # create species-specific df
    sp=samples_2022['Species']==specie
    sp_df=samples_2022[sp]

    for status in statuses:
        d_22["Health_status"].append(status)
        # create new df with each health status within each species 
        status_sp=sp_df["Health_status"]==status
        status_sp_df=sp_df[status_sp]

        colonies=status_sp_df["OldTagNum"].nunique()

        #add num of tagged colonies to dict
        d["Tagged_colonies"].append(colonies)

        #determine num of samples in each health status in each species
        samples=status_sp_df["SampleNum"].nunique()

        #add to dict
        d["Num_samples"].append(samples)
#convert d to df
d_22
#SampleCounts_healthy2019=pd.DataFrame.from_dict(d)
#SampleCounts_healthy2019

print("Species", len(d_22['Species']))
print("Tagged_colonies", len(d_22['Tagged_colonies']))
print("Health_status", len(d_22['Health_status']))
print("Num_samples", len(d_22['Num_samples']))

# %%
# create dictionary with necessary columns 
d={"Year":[],"Species":[], "Health_status":[],"Tagged_colonies":[],"Num_samples":[]}
# create list of years and species
species_list=sample_data['Species'].unique()
years=sample_data['Year'].unique()
statuses=sample_data['Health_status'].unique()
# loop thru each species in healthy 2019 df
for year in years:
    for specie in species_list:
            d["Year"].append(year)

            #create df specific to the year
            df = sample_data["Year"]==year
            samples_year=sample_data[df]
            # add specie name to 'species' col
            d["Species"].append(specie)
            
            for status in statuses:
            # add health status to dict
                d["Health_status"].append(status)

                # loop thru statuses and determine num of samples
                each_status=sample_data["Health_status"]==status
                status_df=sample_data[each_status]
                sample_num=status_df["SampleNum"].nunique()

                #add num of samples to dict
                d["Num_samples"].append(sample_num)

                # determine num of tagged colonies
                sp=samples_year["Species"]==specie
                sp_df=samples_year[sp]
                colonies=sp_df["NewTagNum"].nunique()
                # there are still NAs so this isn't quite right yet 
                #add num of tagged colonies to dict
                d["Tagged_colonies"].append(colonies)

                #determine num of samples
                samples=sp_df["SampleNum"].nunique()

                #add to dict
                d["Num_samples"].append(samples)
#convert d to df

#SummaryTable=pd.DataFrame.from_dict(d)
#SummaryTable
print("year", len(d['Year']))
print("Species", len(d['Species']))
print("Tagged_colonies", len(d['Tagged_colonies']))
print("Health_status", len(d['Health_status']))
print("Num_samples", len(d['Num_samples']))
# Out:
# year 52
# Species 52
# Tagged_colonies 676
# Health_status 676
# Num_samples 1352

# %%
d
# Out:
# {'Year': ['2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024'],
#  'Species': ['OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST ',
#   'OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST ',
#   'OFAV',
#   'PAST',
# ...

# %%
species_list=sample_data['Species'].unique()
species_list
# Out:
# array(['OFAV', 'PAST', 'SSID', 'MCAV', 'PSTR', 'OANN', 'DLAB', 'CNAT',
#        'DL', 'OANN/OFAV?', 'MMEA', 'OFAV/OANN', 'PAST '], dtype=object)

# %%
# Attempt 3: create diff dictionaries and for loops specific to each year then combine?

# create dictionary with necessary columns 
samples_2022={"Species":[], "Tagged_colonies":[], "Health_status":[],"Num_samples":[]}
# create list of species
species_list=sample_data['Species'].unique()

s2022 = sample_data["Year"]=='2022'
year_2022=sample_data[s2022]

# loop thru each species in 2022 df
for specie in species_list:
    # add specie name to 'species' col
    samples_2022["Species"].append(specie)
    
 # determine num of tagged colonies
    sp=year_2022["Species"]==specie
    sp_df=year_2022[sp]
    colonies=sp_df["NewTagNum"].nunique()
    # there are still NAs so this isn't quite right yet 
 # add num of tagged colonies to dict
    samples_2022["Tagged_colonies"].append(colonies)

 # make list of health status options
    statuses=sp_df['Health_status'].unique()
    
 # determine num of samples within each health status
    for status in statuses:
        # add health status to dict
        samples_2022["Health_status"].append(status)
        
        # loop thru statuses and determine num of samples
        status_2022=year_2022["Health_status"]==status
        status_df=year_2022[status_2022]
        sample_num=status_df["SampleNum"].nunique()

        #add to dict
        samples_2022["Num_samples"].append(sample_num)

#convert d to df
samples_2022
print(len(samples_2022["Species"]))
print(len(samples_2022["Tagged_colonies"]))
print(len(samples_2022["Health_status"]))
print(len(samples_2022["Num_samples"]))

#Summary2022=pd.DataFrame.from_dict(samples_2022)
#Summary2022
# Out:
# 13
# 13
# 31
# 31

# %%
samples_2022
# Out:
# {'Species': ['OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST '],
#  'Tagged_colonies': [11, 16, 24, 23, 20, 8, 9, 1, 1, 1, 0, 0, 0],
#  'Health_status': ['Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Healthy',
#   'Diseased_Tissue',
#   nan,
#   'MiSSING',
#   'MISSING',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Healthy',
#   'HealthyNot_Sampled',
#   'Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'MISS_SAMPLE',
#   nan,
#   'Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Healthy',
#   'HealthyTissue',
#   'Healthy',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Healthy',
#   'Healthy',
#   'Healthy'],
#  'Num_samples': [145,
#   87,
#   92,
#   87,
#   145,
#   92,
#   0,
#   0,
#   0,
#   87,
#   92,
#   145,
#   0,
#   145,
#   87,
#   92,
#   0,
# ...
